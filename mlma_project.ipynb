# %% [markdown]
# <a href="https://colab.research.google.com/github/adishri8/MLMAMidtermProject/blob/main/mlma_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("priyankraval/nurse-stress-prediction-wearable-sensors")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 76.2M/76.2M [00:00<00:00, 125MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/priyankraval/nurse-stress-prediction-wearable-sensors/versions/1

# %%
import pandas as pd

df = pd.read_csv("merged_data.csv")
df.head()
df.shape
import numpy as np
# Out:
# /tmp/ipython-input-666/576518248.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("merged_data.csv")

# %%
plt.scatter(df["HR"], df["label"])

np.std(df)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_698/964094849.py in <cell line: 0>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df[1:50]
# Out:
#         X      Y     Z       EDA     HR   TEMP  id  \
# 1   -20.0  -69.0  -3.0  6.769995  99.43  31.17  15
# 2   -31.0  -78.0 -15.0  6.769995  99.43  31.17  15
# 3   -47.0  -65.0 -38.0  6.769995  99.43  31.17  15
# 4   -67.0  -57.0 -53.0  6.769995  99.43  31.17  15
# 5    -9.0  -57.0 -32.0  6.769995  99.43  31.17  15
# 6     9.0  -68.0  -2.0  6.769995  99.43  31.17  15
# 7    -6.0  -74.0  17.0  6.769995  99.43  31.17  15
# 8    -1.0  -68.0 -19.0  6.805877  99.43  31.17  15
# 9    -9.0  -63.0 -37.0  6.805877  99.43  31.17  15
# 10  -41.0  -73.0 -29.0  6.805877  99.43  31.17  15
# 11  -52.0  -74.0 -22.0  6.805877  99.43  31.17  15
# 12  -22.0  -78.0  -9.0  6.805877  99.43  31.17  15
# 13  -20.0  -73.0 -14.0  6.805877  99.43  31.17  15
# 14  -26.0  -71.0 -22.0  6.805877  99.43  31.17  15
# 15  -24.0  -67.0 -25.0  6.805877  99.43  31.17  15
# 16  -15.0  -60.0 -18.0  6.789217  99.43  31.17  15
# 17  -29.0  -53.0 -34.0  6.789217  99.43  31.17  15
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(df["HR"]);

# plt.hist(df["label"])

# %%
plt.hist(df["label"])
# Out:
# (array([2162246.,       0.,       0.,       0.,       0.,  806222.,
#               0.,       0.,       0., 8540583.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
# cleaning / pre-processing data

# remove accelerometer data

cleaned_dataset = df.drop(["X", "Y", "Z"], axis=1)
cleaned_dataset.head()

type(df["datetime"][0])
# Out:
# str

# %%
print(df.shape)
# Out:
# (11509051, 9)

# %%
for nurse in nurses:
    one_patient = df[df["id"] == nurse]
    print(len(one_patient))
# Out:
# 262144
# 46987
# 865930
# 825549
# 591363
# 1377342
# 253447
# 62099
# 1310720
# 423763
# 61808
# 524288
# 420875
# 0

# %%
plt.plot()
