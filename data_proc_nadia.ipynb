# %%
import kagglehub
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("/Users/nadia.momtaz/Downloads/merged_data2.csv")
df.head()
df.shape
import numpy as np
#from google.colab import drive
#drive.mount('/content/drive')

# Then upload the file to Drive and read it like:
# df = pd.read_csv("/content/drive/MyDrive/merged_data 2.csv")
# Out:
# /var/folders/kr/npf8ybm56gx6gndx2dby4c8r0000gn/T/ipykernel_35909/4240435452.py:5: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/nadia.momtaz/Downloads/merged_data2.csv")

# %%
df.head()
# Out:
#       X     Y     Z       EDA     HR   TEMP  id  \
# 0 -13.0 -61.0   5.0  6.769995  99.43  31.17  15
# 1 -20.0 -69.0  -3.0  6.769995  99.43  31.17  15
# 2 -31.0 -78.0 -15.0  6.769995  99.43  31.17  15
# 3 -47.0 -65.0 -38.0  6.769995  99.43  31.17  15
# 4 -67.0 -57.0 -53.0  6.769995  99.43  31.17  15
#
#                         datetime  label
# 0  2020-07-08 14:03:00.000000000    2.0
# 1  2020-07-08 14:03:00.031249920    2.0
# 2  2020-07-08 14:03:00.062500096    2.0
# 3  2020-07-08 14:03:00.093750016    2.0
# 4  2020-07-08 14:03:00.124999936    2.0

# %%
patients = np.unique(df["id"].astype(str))
df["time"] = pd.to_datetime(df["datetime"])

df["seconds_elapsed"] = (df["time"] - df["time"].min()).dt.total_seconds()
for i in range (len(patients)):
    one_patient = df[df["id"] == patients[i]]
    sample = one_patient.sample(5000, random_state=42).sort_values("seconds_elapsed")
    # sample = one_patient.iloc[420000:]
    plt.plot(sample['seconds_elapsed'], sample['HR'])
    plt.xlabel("time (seconds elapsed)")
    plt.ylabel("HR")
    plt.title(f"Nurse {i+1}'s HR over time")
    plt.show()

# %%
# Visualize the distribution of HR, EDA, and TEMP for each nurse

for i in range (len(patients)):
    one_patient = df[df["id"] == patients[i]]
    plt.hist(one_patient["HR"], bins=50)
    plt.xlabel("HR")
    plt.ylabel("Frequency")
    plt.title("Distribution of HR")
    plt.show()

    plt.hist(one_patient["EDA"], bins=50, color='orange')
    plt.xlabel("EDA")
    plt.ylabel("Frequency")
    plt.title("Distribution of EDA")
    plt.show()

    plt.hist(one_patient["TEMP"], bins=50, color='green')
    plt.xlabel("TEMP")
    plt.ylabel("Frequency")
    plt.title("Distribution of TEMP") 
    plt.show()
