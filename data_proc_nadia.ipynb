# %%
import kagglehub
import matplotlib.pyplot as plt

# Download latest version
path = kagglehub.dataset_download("priyankraval/nurse-stress-prediction-wearable-sensors")

print("Path to dataset files:", path)

import pandas as pd

df = pd.read_csv("/Users/nadia.momtaz/Downloads/merged_data2.csv")
df.head()
df.shape
import numpy as np
# Out:
# Using Colab cache for faster access to the 'nurse-stress-prediction-wearable-sensors' dataset.
# Path to dataset files: /kaggle/input/nurse-stress-prediction-wearable-sensors
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_33927/539503236.py in <cell line: 0>()
#       9 import pandas as pd
#      10
# ---> 11 df = pd.read_csv("/Users/nadia.momtaz/Downloads/merged_data2.csv")
#      12 df.head()
#      13 df.shape
#
# ...

# %%
import os
path = "/Users/nadia.momtaz/Downloads/merged_data 2.csv"
print(os.path.exists(path))
# Out:
# False

# %%
patients = np.unique(df["id"].astype(str))
df["time"] = pd.to_datetime(df["datetime"])

df["seconds_elapsed"] = (df["time"] - df["time"].min()).dt.total_seconds()
for i in range (len(patients)):
    one_patient = df[df["id"] == patients[i]]
    sample = one_patient.sample(50000, random_state=42).sort_values("seconds_elapsed")
    # sample = one_patient.iloc[420000:]
    plt.plot(sample['seconds_elapsed'], sample['HR'])
    plt.xlabel("time (seconds elapsed)")
    plt.ylabel("HR")
    plt.title(f"Nurse {i+1}'s HR over time")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_33927/959265790.py in <cell line: 0>()
# ----> 1 patients = np.unique(df["id"].astype(str))
#       2
#       3 for i in range (len(patients)):
#       4     one_patient = df[df["id"] == patients[i]]
#       5     sample = one_patient.sample(50000, random_state=42).sort_values("seconds_elapsed")
#
# NameError: name 'np' is not defined
